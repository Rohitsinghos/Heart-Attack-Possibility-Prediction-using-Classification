# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
heartds = pd.read_csv('heart.csv')

# %%
heartds.head(50)
# Out:
#     ï»¿age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0       63    1   3       145   233    1        0      150      0      2.3
# 1       37    1   2       130   250    0        1      187      0      3.5
# 2       41    0   1       130   204    0        0      172      0      1.4
# 3       56    1   1       120   236    0        1      178      0      0.8
# 4       57    0   0       120   354    0        1      163      1      0.6
# 5       57    1   0       140   192    0        1      148      0      0.4
# 6       56    0   1       140   294    0        0      153      0      1.3
# 7       44    1   1       120   263    0        1      173      0      0.0
# 8       52    1   2       172   199    1        1      162      0      0.5
# 9       57    1   2       150   168    0        1      174      0      1.6
# 10      54    1   0       140   239    0        1      160      0      1.2
# ...

# %%
X = heartds.drop(columns='trestbps', axis=1)
Y = heartds['trestbps']

# %%
print(X)
# Out:
#      ï»¿age  sex  cp  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# 0        63    1   3   233    1        0      150      0      2.3      0   0
# 1        37    1   2   250    0        1      187      0      3.5      0   0
# 2        41    0   1   204    0        0      172      0      1.4      2   0
# 3        56    1   1   236    0        1      178      0      0.8      2   0
# 4        57    0   0   354    0        1      163      1      0.6      2   0
# ..      ...  ...  ..   ...  ...      ...      ...    ...      ...    ...  ..
# 298      57    0   0   241    0        1      123      1      0.2      1   0
# 299      45    1   3   264    0        1      132      0      1.2      1   0
# 300      68    1   0   193    1        1      141      0      3.4      1   2
# 301      57    1   0   131    0        1      115      1      1.2      1   1
# 302      57    0   1   236    0        0      174      0      0.0      1   1
#
#      thal  target
# 0       1       1
# ...

# %%
print(Y)
# Out:
# 0      145
# 1      130
# 2      130
# 3      120
# 4      120
#       ...
# 298    140
# 299    110
# 300    144
# 301    130
# 302    130
# Name: trestbps, Length: 303, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, Y_train, Y_test)
# Out:
# (303, 13) 237    140
# 106    160
# 10     140
# 153    146
# 77     140
#       ...
# 75     135
# 22     140
# 72     130
# 15     120
# 168    130
# Name: trestbps, Length: 242, dtype: int64 99     130
# 296    124
# 89     100
# 30     105
# 234    130
#       ...
# 173    132
# 94     112
# 161    132
# 216    130
# 91     132
# Name: trestbps, Length: 61, dtype: int64

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
training_data_prediction = regressor.predict(X_train)

# %%
r2_train = metrics.r2_score(Y_train, training_data_prediction)
print('R squared vale : ', r2_train)
# Out:
# R squared vale :  0.15777954311756381

# %%
test_data_prediction =regressor.predict(X_test)

# %%
r2_test = metrics.r2_score(Y_test, test_data_prediction)
print('R squared vale : ', r2_test)
# Out:
# R squared vale :  0.056307973904520914

# %%
inputi = (17,1,1,120, 1,0,120,0, 3.1, 1, 1, 3, 0)

input_as_numpy_array = np.asarray(inputi)

input_reshaped = input_as_numpy_array.reshape(1,-1)

test = regressor.predict(input_reshaped)

print('The heart attack prediction trestbps is ', test)

_state=2;
# Out:
# The heart attack prediction trestbps is  [117.40511751]
